# %%
import sys, geopandas as gpd, pandas as pd
import warnings 
warnings.filterwarnings('ignore')
sys.path.append("..")
from src import user_function as utils

# %% [markdown]
# # Principal data

# %%
shp_data = gpd.read_file("../data/0_shapefile/pos_gdf.shp").to_crs(epsg=4326)
shp_data.head(2)
# Out:
#    index  id_distr_b  year  newid  baseline_P  \
# 0      0         204  2015   3185         473
# 1      1         203  2015   3185         472
#
#                                             geometry
# 0  POLYGON ((71.48246 34.14608, 71.48349 34.14576...
# 1  POLYGON ((71.48246 34.14608, 71.48349 34.14576...

# %%
shp_data.shape
# Out:
# (163, 6)

# %% [markdown]
# # Rasters Data

# %% [markdown]
# ## Test example

# %%
nightlight_tiff = "../data/8_night_light/pk_night_light_harm.tiff"

# %%
collect_test = pd.DataFrame()
sample_shp = shp_data.sample(4, random_state=1)
for i in range(len(sample_shp)):
    row = sample_shp.iloc[i:i+1]
    df = utils.crop_raster(nightlight_tiff, row)
    df = utils.points_inside(df, row)
    stats = utils.simple_metrics(df, target_name = "nightlight_test")
    collect_test = pd.concat((collect_test, stats))

# %%
collect_test
# Out:
#     index  id_distr_bank  year  newid  baseline_PSU  nightlight_test_mean  \
# 3      44            201  2015   3243           460             59.500000
# 9      47            194  2015   3245           469             36.846153
# 11     94            227  2015  13175           176             10.800000
# 38     78             18  2015  13102           142             24.385542
#
#     nightlight_test_sd  nightlight_test_sum
# 3             0.707107                119.0
# 9             5.257473                479.0
# 11            2.709460                378.0
# 38           16.896263               2024.0

# %% [markdown]
# ### Using Package

# %%
utils.get_metrics(nightlight_tiff, sample_shp, 'nightlight_test')
# Out:
#     index  id_distr_bank  year  newid  baseline_PSU  nightlight_test_mean  \
# 3      44            201  2015   3243           460             59.500000
# 9      47            194  2015   3245           469             36.846153
# 11     94            227  2015  13175           176             10.800000
# 38     78             18  2015  13102           142             24.385542
#
#     nightlight_test_sd  nightlight_test_sum
# 3             0.707107                119.0
# 9             5.257473                479.0
# 11            2.709460                378.0
# 38           16.896263               2024.0

# %% [markdown]
# ## Population

# %%
pop_tif = "../data/1_density/pak_ppp_2018_1km_Aggregated.tif"
pop_name = "population"
pop_info = utils.get_metrics(pop_tif, shp_data, pop_name)
utils.save_data(pop_info, pop_name, head_name="1_metrics_", path_dir='../output/')
pop_info.head()
# Out:
#     index  id_distr_bank  year  newid  baseline_PSU  population_mean  \
# 1       0            204  2015   3185           473      1186.241577
# 1       1            203  2015   3185           472      1186.241577
# 6       2            206  2015   3186           475      6661.680664
# 59      3            141  2015   3189           582       207.739807
# 15      4            140  2015   3191           567        48.604107
#
#     population_sd  population_sum
# 1      319.477356    28469.798828
# 1      319.477356    28469.798828
# 6     1596.328247    33308.402344
# 59     389.778229   106570.523438
# 15      76.729019    58276.324219

# %% [markdown]
# ## Motor

# %%
motor_tif = "../data/5_friction_surface/2020_motorized_friction_surface.geotiff"
motor_name = "motor"
motor_info = utils.get_metrics(motor_tif, shp_data, motor_name)
utils.save_data(motor_info, motor_name, head_name="5_metrics_", path_dir='../output/')
motor_info.head()
# Out:
#     index  id_distr_bank  year  newid  baseline_PSU  motor_mean  motor_sd  \
# 1       0            204  2015   3185           473    0.002363  0.004645
# 1       1            203  2015   3185           472    0.002363  0.004645
# 11      2            206  2015   3186           475    0.001125  0.000377
# 59      3            141  2015   3189           582    0.007954  0.007866
# 14      4            140  2015   3191           567    0.015261  0.008198
#
#     motor_sum
# 1    0.059079
# 1    0.059079
# 11   0.004500
# 59   4.080442
# 14  18.344032

# %% [markdown]
# ## Altitude

# %%
srtm_tif = "../data/6_srtm/PK_srtm.tif"
srtm_name = "altitude"
srtm_info = utils.get_metrics(srtm_tif, shp_data, srtm_name)
utils.save_data(srtm_info, srtm_name, head_name="6_metrics_", path_dir='../output/')
srtm_info.head()
# Out:
#      index  id_distr_bank  year  newid  baseline_PSU  altitude_mean  \
# 4        0            204  2015   3185           473     326.876068
# 4        1            203  2015   3185           472     326.876068
# 4        2            206  2015   3186           475     357.257202
# 582      3            141  2015   3189           582       0.100000
# 150      4            140  2015   3191           567     130.559204
#
#      altitude_sd  altitude_sum
# 4       3.614312      757045.0
# 4       3.614312      757045.0
# 4       5.082992      173627.0
# 582     0.100000           0.1
# 150    92.660477    15675461.0

# %% [markdown]
# ## Nightlight

# %% [markdown]
# #### Harm

# %%
nightlight_h_tiff = "../data/8_night_light/pk_night_light_harm.tiff"
name_night_h = "nightlight_harm"
info_night_harm = utils.get_metrics(nightlight_h_tiff, shp_data, name_night_h)
info_night_harm.head()
# Out:
#     index  id_distr_bank  year  newid  baseline_PSU  nightlight_harm_mean  \
# 9       0            204  2015   3185           473              8.318182
# 9       1            203  2015   3185           472              8.318182
# 12      2            206  2015   3186           475             53.666668
# 58      3            141  2015   3189           582             16.397638
# 47      4            140  2015   3191           567              2.847627
#
#     nightlight_harm_sd  nightlight_harm_sum
# 9             0.476731                183.0
# 9             0.476731                183.0
# 12            2.081666                161.0
# 58           14.010821               8330.0
# 47            3.267404               3420.0

# %%
utils.save_data(info_night_harm, name_night_h, head_name="8_metrics_", path_dir='../output/')

# %% [markdown]
# #### Original

# %%
nightlight_tiff = '../data/8_night_light/pk_night_light.tiff'
name_night = "nightlight"
info_night = utils.get_metrics(nightlight_tiff, shp_data, name_night)
utils.save_data(info_night, name_night, head_name="8_metrics_", path_dir="../output/")

# %%
info_night.head()
# Out:
#      index  id_distr_bank  year  newid  baseline_PSU  nightlight_mean  \
# 17       0            204  2015   3185           473     4.761764e-01
# 17       1            203  2015   3185           472     4.761764e-01
# 9        2            206  2015   3186           475     9.440191e+00
# 117      3            141  2015   3189           582    -1.666667e+35
# 92       4            140  2015   3191           567     5.026005e-02
#
#      nightlight_sd  nightlight_sum
# 17        0.303871    4.380823e+01
# 17        0.303871    4.380823e+01
# 9         3.005657    1.510431e+02
# 117       0.100000   -3.400000e+38
# 92        0.259624    2.413488e+02
